# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./mml/data/Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# histogram
sns.histplot(
    x=df["Churn"], alpha=0.5, data=df, hue="Churn", palette="cool", 
)
plt.title("Customer Churn Distribution")
plt.xlabel('Churn')
plt.ylabel('Count')


plt.yticks([1000,2000,3000,4000,5000], ['1k','2k','3k','4k','5k'])

plt.show()

# %%
# get a single column
df["TotalCharges"][487:491]
# Out:
# 487    6201.95
# 488
# 489      74.35
# 490    6597.25
# Name: TotalCharges, dtype: object

# %%
val = df["TotalCharges"].iloc[488]
print(f"Value: '{val}'")
print(f"Type: {type(val)}")
print(f"Length: {len(val)}")
print(f"Is null?: {pd.isnull(val)}")
print(f"Is empty string?: {val == ''}")
df_cp = df.copy()
# Out:
# Value: ' '
# Type: <class 'str'>
# Length: 1
# Is null?: False
# Is empty string?: False

# %%
df_cp["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")


df_cp.fillna(df_cp['TotalCharges'].mean(), inplace=True)

df_cp.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64
